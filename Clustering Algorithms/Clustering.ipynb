# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# %%
X,Y = make_classification(n_samples=1000, n_features=2, n_informative=2, n_redundant=0,n_clusters_per_class=1,random_state=4)

# %%
X
# Out:
# array([[ 1.22515974, -0.95173116],
#        [ 1.01630365, -1.72517506],
#        [ 0.33534004, -1.7248955 ],
#        ...,
#        [ 1.54270795, -0.05566478],
#        [ 0.81664566, -1.2509187 ],
#        [ 1.13782254, -1.26151957]])

# %%
for class_value in range(2):
  row_ix = np.where(Y==class_value)
  plt.scatter(X[row_ix,0],X[row_ix,1])
plt.show()

# %% [markdown]
# ## K-Means Clustering

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=2)

# %%
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
Y_ = model.predict(X)
#print(Y_)

# %%
clusters = np.unique(Y_)
print(clusters)
# Out:
# [0 1]

# %%
for cluster in clusters:
  row_ix = np.where(Y_ == cluster)
  plt.scatter(X[row_ix,0],X[row_ix,1])
plt.show()

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
model = DBSCAN(eps=0.3,min_samples=10)

# %%
model.fit(X)
# Out:
# DBSCAN(algorithm='auto', eps=0.3, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=10, n_jobs=None, p=None)

# %%
Y_ = model.fit_predict(X)

# %%
clusters = np.unique(Y_)
for cluster in clusters:
  row_ix = np.where(Y_ == cluster)
  plt.scatter(X[row_ix,0],X[row_ix,1])
plt.show()

# %% [markdown]
# ## Affinity Propagation

# %%
import matplotlib
matplotlib.rc_file_defaults()

# %%
from sklearn.datasets import make_blobs

# %%
X,Y = make_blobs(n_samples=400, centers=4, random_state=2, n_features=2)

# %%
plt.figure(0)
plt.scatter(X[:,0],X[:,1],c=Y)
plt.show()

# %%
from sklearn.cluster import AffinityPropagation

# %%
model = AffinityPropagation(preference=-80,damping=0.9)

# %%
model.fit(X)
# Out:
# AffinityPropagation(affinity='euclidean', convergence_iter=15, copy=True,
#                     damping=0.9, max_iter=200, preference=-80, verbose=False)

# %%
Y_ = model.predict(X)

# %%
clusters = np.unique(Y_)
for cluster in clusters:
  row_ix = np.where(Y_ == cluster)
  plt.scatter(X[row_ix,0],X[row_ix,1])
plt.show()

# %% [markdown]
# ## Agglomerative Hierarchical Clustering

# %%
X,Y = make_classification(n_samples=1000, n_features=2, n_informative=2, n_redundant=0,n_clusters_per_class=1,random_state=4)
#X,Y = make_blobs(n_samples=400, centers=4, random_state=2, n_features=2)

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
model = AgglomerativeClustering(n_clusters=2)

# %%
Y_ = model.fit_predict(X)

# %%
clusters = np.unique(Y_)
for cluster in clusters:
  row_ix = np.where(Y_ == cluster)
  plt.scatter(X[row_ix,0],X[row_ix,1])
plt.show()
